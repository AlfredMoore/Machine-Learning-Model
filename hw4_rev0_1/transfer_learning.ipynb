# %% [markdown]
# # EECS 545 (WN 2023) Homework 4: Transfer Learning
#
# <span class="instruction">Before starting the assignment, please fill in the following cell.</span>

# %%
###################################################################
# Enter your first and last name, e.g. "John Doe"                 #
# for example                                                     #
# __NAME__ = "Anthony Liu"                                        #
# __UNIQID__ = "anthliu"                                          #
###################################################################
# raise NotImplementedError("TODO: Add your implementation here.")
__NAME__ = "Mo Xu"                                        #
__UNIQID__ = "xmo"                                          #
###################################################################
#                        END OF YOUR CODE                         #
###################################################################

print(f"Your name and email: {__NAME__} <{__UNIQID__}@umich.edu>")
assert __NAME__ and __UNIQID__
# Out:
# Your name and email: Mo Xu <xmo@umich.edu>

# %% [markdown]
# # Transfer Learning
# In this notebook, you will test your transfer learning implementation from `transfer_learning.py`

# %% [markdown]
# ## Setup code
# Before getting started, we need to run some boilerplate code to set up our environment. You'll need to rerun this setup code each time you start the notebook. Let's start by checking whether we are using Python 3.10 or higher.

# %%
import sys
if sys.version_info[0] < 3:
    raise Exception("You must use Python 3")

if sys.version_info[1] < 10:
    print("Autograder will execute your code based on Python 3.10 environment. Please use Python 3.10 or higher to prevent any issues")
    print("You can create a conda environment with Python 3.10 like 'conda create --name eecs545 python=3.10'")
    raise Exception("Python 3 version is too low: {}".format(sys.version))
else:
    print("You are good to go")
# Out:
# You are good to go

# %% [markdown]
# First, run this cell load the [autoreload](https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html) extension. This allows us to edit `.py` source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Then, we run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
# install required libraries
# %pip install numpy==1.24.1 matplotlib==3.6.2 scikit-learn==1.2.0

# import libraries
import math
import numpy as np
import matplotlib.pyplot as plt

# set figure size
plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['font.size'] = 16
# Out:
# Requirement already satisfied: numpy==1.24.1 in f:\anaconda3\envs\ece545\lib\site-packages (1.24.1)
# Requirement already satisfied: matplotlib==3.6.2 in f:\anaconda3\envs\ece545\lib\site-packages (3.6.2)
# Requirement already satisfied: scikit-learn==1.2.0 in f:\anaconda3\envs\ece545\lib\site-packages (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in f:\anaconda3\envs\ece545\lib\site-packages (from matplotlib==3.6.2) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in f:\anaconda3\envs\ece545\lib\site-packages (from matplotlib==3.6.2) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in f:\anaconda3\envs\ece545\lib\site-packages (from matplotlib==3.6.2) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in f:\anaconda3\envs\ece545\lib\site-packages (from matplotlib==3.6.2) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in f:\anaconda3\envs\ece545\lib\site-packages (from matplotlib==3.6.2) (4.39.0)
# Requirement already satisfied: cycler>=0.10 in f:\anaconda3\envs\ece545\lib\site-packages (from matplotlib==3.6.2) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in f:\anaconda3\envs\ece545\lib\site-packages (from matplotlib==3.6.2) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in f:\anaconda3\envs\ece545\lib\site-packages (from matplotlib==3.6.2) (3.0.9)
# Requirement already satisfied: scipy>=1.3.2 in f:\anaconda3\envs\ece545\lib\site-packages (from scikit-learn==1.2.0) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in f:\anaconda3\envs\ece545\lib\site-packages (from scikit-learn==1.2.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in f:\anaconda3\envs\ece545\lib\site-packages (from scikit-learn==1.2.0) (3.1.0)
# Requirement already satisfied: six>=1.5 in f:\anaconda3\envs\ece545\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.6.2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Next, we need to make sure pytorch is installed. The following command will install pytorch if you haven't installed it before. Depending on your OS and GPU hardware, this may install a CPU or GPU version. If you want to use a GPU with PyTorch (which will exponentially speed up your computation time) you can follow the instructions on the pytorch [official website](https://pytorch.org/get-started/locally/). In this problem set a CPU-only pytorch is sufficient.

# %%
# %pip install torch torchvision
# Out:
# Requirement already satisfied: torch in f:\anaconda3\envs\ece545\lib\site-packages (1.13.1)
# Requirement already satisfied: torchvision in f:\anaconda3\envs\ece545\lib\site-packages (0.14.1)
# Requirement already satisfied: typing-extensions in f:\anaconda3\envs\ece545\lib\site-packages (from torch) (4.5.0)
# Requirement already satisfied: numpy in f:\anaconda3\envs\ece545\lib\site-packages (from torchvision) (1.24.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in f:\anaconda3\envs\ece545\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: requests in f:\anaconda3\envs\ece545\lib\site-packages (from torchvision) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\anaconda3\envs\ece545\lib\site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda3\envs\ece545\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda3\envs\ece545\lib\site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in f:\anaconda3\envs\ece545\lib\site-packages (from requests->torchvision) (1.26.15)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
# check if CUDA is available on torch
print('PyTorch CUDA is available?', torch.cuda.is_available())
# Out:
# PyTorch CUDA is available? False

# %%
from IPython.display import display_html, HTML

display_html(HTML('''
<style type="text/css">
  .instruction { background-color: yellow; font-weight:bold; padding: 3px; }
</style>
'''));
# Out:
# <style type="text/css">
#   .instruction { background-color: yellow; font-weight:bold; padding: 3px; }
# </style>

# %% [markdown]
# Running the following cell allow us to import from `transfer_learning.py`. If it works correctly, it should print the message:
# ```Hello from transfer_learning.py```

# %%
from transfer_learning import hello
hello()
# Out:
# Hello from transfer_learning.py!

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ## Downloading the dataset
#
# We'll be doing some transfer learning on [hymenopteras](https://en.wikipedia.org/wiki/Hymenoptera). (Warning, lots of bugs!)
#
# The dataset can be downloaded through [this link](https://drive.google.com/file/d/1pzQg8ydLM1z7UEUYq52-iFzUCB55b3wz/view?usp=sharing) (45Mb) and unzip the folder into the data directory.
#
# ```
# HW4 /
# --| transfer_learning.ipynb
# --| data /
# ----| hymenoptera_data /
# ------| train /
# ------| ...
# ```

# %% [markdown]
# ## Loading and visualizing the data

# %%
import os
from torchvision import datasets, transforms

# Load data from disk
data_dir = './data/hymenoptera_data'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x))
                  for x in ['train', 'val']}

# %%
# visualize grid
def make_grid(ims, h, w, captions=None):
    for i in range(h):
        for j in range(w):
            if ims[i*w + j] is None:
                continue
            plt.subplot(h, w, i*w + j + 1)
            plt.axis('off')
            plt.imshow(ims[i*w + j])
            if captions is not None and captions[i*w + j] is not None:
                plt.title(captions[i*w + j])

# %%
# sample images from image_datasets
sample_size = 25
rng = np.random.default_rng(545)
idxs = {x: rng.choice(len(image_datasets[x]), sample_size, replace=False)
        for x in ['train', 'val']}
samples = {x: [image_datasets[x][i][0] for i in idxs[x]]
           for x in ['train', 'val']}
sample_classes = {x: [image_datasets[x].classes[image_datasets[x][i][1]] for i in idxs[x]]
                  for x in ['train', 'val']}

# %%
plt.suptitle('Train samples')
make_grid(samples['train'], sample_size // 5, 5, sample_classes['train'])

# %%
plt.suptitle('Validation samples')
make_grid(samples['val'], sample_size // 5, 5, sample_classes['val'])

# %% [markdown]
# ## Preprocessing images
#
# Before we can start training with these images, we need to make sure
# 1. The image sizes are correct (224 x 224) images
# 2. The images are normalized to the mean and standard deviation in each channel. Normalization will almost always improve NN performance by removing scaling patterns in the input data.
# In addition, since we are transfer learning on an *ImageNet model*, we need to apply the same normalization as applied in the original model. This is: normalized = (image - mu) / std, where mu = [0.485, 0.456, 0.406] and std = [0.229, 0.224, 0.225].
# These were are the mean and standard deviations of each channel in the ImageNet dataset.
#
# In addtion, we can apply some image augmentations to the training data. E.g. we can randomly crop and randomly flip the training images. This way, we can artificially learn on more training data and improve performance!
#
# We can visualize some of these transformations as follows, for which pytorch gives some convenient functions.

# %%
im = image_datasets['train'][7][0]
grid = [
    im,
    transforms.CenterCrop(224)(im),
    transforms.RandomResizedCrop(224)(im),
    transforms.RandomResizedCrop(224)(im),
    transforms.RandomHorizontalFlip()(im),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])(transforms.ToTensor()(im)).permute(1, 2, 0),
]
caps = [
    'original',
    'Center crop',
    'Random crop',
    'Random crop',
    'Random flip',
    'Normalized (clipped)',
]
make_grid(grid, h=2, w=3, captions=caps)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Putting everything together
#
# <span class="instruction">Complete the missing code segments in `transfer_learning.py` marked by the TODOs.</span>

# %%
import os
from torchvision import datasets, transforms

data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# Load data from disk
data_dir = './data/hymenoptera_data'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
               shuffle=True, num_workers=4)
               for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

# %% [markdown]
# Set the device to CUDA if it's available, otherwise we'll use CPU.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Finetune the pre-trained model
#
# *Warning:* If you are training on CPU, this may take some time (up to a few hours).
# To give you an idea of whether your code is working or not, our instructor solution gets around ~65%, ~75% and 80% after 1, 2, and 3 epochs.
# These numbers are not exact and may fluctuate due to randomization.

# %%
from transfer_learning import finetune

NUM_EPOCHS = 5# Feel free to train more epochs if you have time
model_ft = finetune(device, dataloaders, dataset_sizes, class_names, num_epochs=NUM_EPOCHS)
# Out:
# Performance of pre-trained model without finetuning
# Training complete in 0m 10s
# Best val Acc: 0.437908
# Finetune the model
# Epoch 0/4
# ----------
# train Loss: 0.5178 Acc: 0.7213
# val Loss: 0.1584 Acc: 0.9542
# Epoch 1/4
# ----------
# train Loss: 0.5775 Acc: 0.7459
# val Loss: 0.2457 Acc: 0.9281
# Epoch 2/4
# ----------
# train Loss: 0.6427 Acc: 0.7582
# val Loss: 0.4544 Acc: 0.8497
# Epoch 3/4
# ----------
# train Loss: 0.5642 Acc: 0.7992
# val Loss: 0.4222 Acc: 0.8431
# Epoch 4/4
# ----------
# train Loss: 0.5524 Acc: 0.8156
# val Loss: 1.2938 Acc: 0.6078
# Training complete in 3m 13s
# Best val Acc: 0.954248

# %%
mu = torch.tensor([0.485, 0.456, 0.406])
std = torch.tensor([0.229, 0.224, 0.225])
unnormalize = lambda t: t.permute(1, 2, 0) * std + mu

# %%
from transfer_learning import visualize_model

num_images = 6
tensors, captions = visualize_model(device, dataloaders, model_ft, class_names, num_images=num_images)
images = [unnormalize(t) for t in tensors]
plt.suptitle('Finetuned Model Predictions')
make_grid(images, h=num_images // 3, w=3, captions=captions)

# %% [markdown]
# ## Freeze the parameters in pre-trained model and train the final fc layer
# *Warning:* If you are training on CPU, this may take some time (up to a few hours).
# To give you an idea of whether your code is working or not, our instructor solution gets around ~65%, ~75% and 80% after 1, 2, and 3 epochs.
# These numbers are not exact and may fluctuate due to randomization.

# %%
from transfer_learning import freeze

NUM_EPOCHS = 5# Feel free to train with more epochs if you have time
model_conv = freeze(device, dataloaders, dataset_sizes, class_names, num_epochs=NUM_EPOCHS)
# Out:
# Performance of pre-trained model without finetuning
# Training complete in 0m 9s
# Best val Acc: 0.313725
# Finetune the model
# Epoch 0/4
# ----------
# train Loss: 0.6215 Acc: 0.6434
# val Loss: 0.3465 Acc: 0.8562
# Epoch 1/4
# ----------
# train Loss: 0.6238 Acc: 0.7500
# val Loss: 0.3534 Acc: 0.8431
# Epoch 2/4
# ----------
# train Loss: 0.5479 Acc: 0.7746
# val Loss: 0.1475 Acc: 0.9673
# Epoch 3/4
# ----------
# train Loss: 0.4813 Acc: 0.7910
# val Loss: 0.2557 Acc: 0.8954
# Epoch 4/4
# ----------
# train Loss: 0.3890 Acc: 0.8320
# val Loss: 0.3923 Acc: 0.8431
# Training complete in 1m 58s
# Best val Acc: 0.967320

# %%
num_images = 6
tensors, captions = visualize_model(device, dataloaders, model_conv, class_names, num_images=num_images)
images = [unnormalize(t) for t in tensors]
plt.suptitle('Frozen Model Predictions')
make_grid(images, h=num_images // 3, w=3, captions=captions)

# %% [markdown]
# How did you do? Report the accuracy on the validation dataset for both the finetuned and frozen scenarios in your final report.
